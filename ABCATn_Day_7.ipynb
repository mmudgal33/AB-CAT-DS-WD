# %% [markdown]
# # **Instructions**
#
# ### **As part of your preparation for the ABCAT (AlmaBetter Comprehensive Assessment Test), we want to ensure you are fully aware of the test details and how to best prepare. Thus, we are providing the test pattern which will help you to prepare for the test in 10 days duration.**
#
# **Try to solve and understand each question so that you score well in the proctered test of ABCAT.**
#
# The test will contain
# - Frontend and Backend MCQ questions
# - Javascript Coding
# - Technical fluency
# - Written and Communication Fluency
#
# **Note:**
#
# 1. These test are only for practice and reference purpose. The test questions might differ from these but will cover the similar concepts as in your curriculum.
#
# 2. If you face any kind of difficulty while solving the questions or achieving the required answers, please feel free to connect at the LIVE SUPPORT to connect with SMEs.
#
# 3. The questions related to **M4 - Backend Development** and **M5 - Practical Software Engineering** are OPTIONAL and can be skipped for now.

# %% [markdown]
# # **MCQ Questions**

# %% [markdown]
# ### Frontend (FE) MCQs
#
# 1. **What is the default value of the `position` property in CSS?**
#    - A. `absolute`
#    - B. `relative`
#    - C. `static`
#    - D. `fixed`
#    - **Answer**: C. `static`
#
# 2. **Which of the following is a valid way to create a JavaScript promise?**
#    - A. `let promise = new Promise(function(resolve, reject) {...});`
#    - B. `let promise = Promise.resolve(function(resolve, reject) {...});`
#    - C. `let promise = Promise.reject();`
#    - D. `let promise = new Promise.resolve(function(resolve) {...});`
#    - **Answer**: A. `let promise = new Promise(function(resolve, reject) {...});`
#
# 3. **Which of the following is used to add comments in a JSX file?**
#    - A. `// comment`
#    - B. `/* comment */`
#    - C. `{/* comment */}`
#    - D. `<!-- comment -->`
#    - **Answer**: C. `{/* comment */}`
#
# 4. **What does the `flex-grow` property do in Flexbox?**
#    - A. It specifies how much a flex item will grow relative to other flex items.
#    - B. It controls the size of the flex container.
#    - C. It allows flex items to shrink when there is not enough space.
#    - D. It aligns items along the flex container’s cross axis.
#    - **Answer**: A. It specifies how much a flex item will grow relative to other flex items.
#
# 5. **Which method is used to add a new element at the end of an array in JavaScript?**
#    - A. `push()`
#    - B. `append()`
#    - C. `add()`
#    - D. `concat()`
#    - **Answer**: A. `push()`
#
# ### Medium to Hard FE MCQs
#
# 6. **Which of the following CSS properties is used to create a layout with multiple columns?**
#    - A. `display: grid;`
#    - B. `column-count`
#    - C. `display: inline;`
#    - D. `flex-wrap: wrap;`
#    - **Answer**: B. `column-count`
#
# 7. **In React, what is the purpose of `shouldComponentUpdate()`?**
#    - A. To update the state of the component.
#    - B. To prevent unnecessary re-renders of a component.
#    - C. To initiate a component’s render process.
#    - D. To update props when state changes.
#    - **Answer**: B. To prevent unnecessary re-renders of a component.
#
# 8. **What does the `apply()` method in JavaScript do?**
#    - A. It is used to execute a function, taking arguments as an array.
#    - B. It applies changes directly to a DOM element.
#    - C. It creates a new function from an existing one with added functionality.
#    - D. It applies a CSS style to all selected elements.
#    - **Answer**: A. It is used to execute a function, taking arguments as an array.
#
# 9. **What is the main difference between `localStorage` and `sessionStorage` in JavaScript?**
#    - A. `sessionStorage` data is persisted across browser sessions, while `localStorage` is not.
#    - B. `sessionStorage` data is deleted when the page is closed, while `localStorage` data persists indefinitely.
#    - C. `localStorage` stores large amounts of data, while `sessionStorage` stores small amounts.
#    - D. There is no difference; both are used interchangeably.
#    - **Answer**: B. `sessionStorage` data is deleted when the page is closed, while `localStorage` data persists indefinitely.
#
# 10. **Which of the following is a new feature introduced in ECMAScript 6 (ES6)?**
#     - A. `let` and `const` declarations
#     - B. `var` and `const` declarations
#     - C. `class` and `module` declarations
#     - D. `function` declarations
#     - **Answer**: A. `let` and `const` declarations
#
# ---
#
# ### Backend (BE) MCQs
#
# 1. **Which of the following is a NoSQL database?**
#    - A. MySQL
#    - B. PostgreSQL
#    - C. MongoDB
#    - D. Oracle
#    - **Answer**: C. MongoDB
#
# 2. **What does the `express.Router()` method in Express.js do?**
#    - A. It defines a route handler for a specific HTTP request method.
#    - B. It binds middleware to specific routes.
#    - C. It creates a new instance of Express.
#    - D. It configures the database connection.
#    - **Answer**: B. It binds middleware to specific routes.
#
# 3. **Which of the following HTTP methods is used to send data to the server to create or update a resource?**
#    - A. `GET`
#    - B. `POST`
#    - C. `DELETE`
#    - D. `OPTIONS`
#    - **Answer**: B. `POST`
#
# 4. **In Node.js, what is the purpose of the `EventEmitter` class?**
#    - A. To handle HTTP requests
#    - B. To enable asynchronous programming by managing events
#    - C. To manage database connections
#    - D. To create new streams for data processing
#    - **Answer**: B. To enable asynchronous programming by managing events
#
# 5. **Which of the following is the correct way to connect a MongoDB database using Mongoose in a Node.js application?**
#    - A. `mongoose.connect('mongodb://localhost/mydb');`
#    - B. `mongoose.connect('mongodb://localhost:27017/mydb');`
#    - C. `mongodb.connect('localhost/mydb');`
#    - D. `mongoose.connect('localhost/mydb');`
#    - **Answer**: B. `mongoose.connect('mongodb://localhost:27017/mydb');`
#
# ### Medium to Hard BE MCQs
#
# 6. **What is the purpose of using `passport.js` in a Node.js application?**
#    - A. For routing requests
#    - B. For authenticating and managing user sessions
#    - C. For managing database queries
#    - D. For caching API responses
#    - **Answer**: B. For authenticating and managing user sessions
#
# 7. **Which SQL keyword is used to retrieve unique records from a database?**
#    - A. `DISTINCT`
#    - B. `UNIQUE`
#    - C. `SELECT`
#    - D. `GROUP BY`
#    - **Answer**: A. `DISTINCT`
#
# 8. **Which of the following is the correct way to handle asynchronous operations in JavaScript?**
#    - A. Using `setTimeout()`
#    - B. Using `async` and `await`
#    - C. Using `var`
#    - D. Using `forEach()`
#    - **Answer**: B. Using `async` and `await`
#
# 9. **What does the `statusCode` property in an HTTP response represent in Express.js?**
#    - A. The URL of the request
#    - B. The number of bytes in the response body
#    - C. The type of the response content
#    - D. The HTTP status code for the response
#    - **Answer**: D. The HTTP status code for the response
#
# 10. **In RESTful API design, which HTTP method is typically used to update an existing resource?**
#     - A. `GET`
#     - B. `POST`
#     - C. `PUT`
#     - D. `DELETE`
#     - **Answer**: C. `PUT`

# %% [markdown]
# # **JS Coding**
#
# **Try to solve each question on your own and understand the logic behind each question.**

# %% [markdown]
# ### 1. **Find the Missing Number in an Array**
#
# **Question**: Given an array of numbers from 1 to n with one number missing, find the missing number.
#
# ```javascript
# function findMissingNumber(arr, n) {
#     const total = (n * (n + 1)) / 2;
#     const sum = arr.reduce((acc, curr) => acc + curr, 0);
#     return total - sum;
# }
#
# // Example usage
# const arr = [1, 2, 4, 5, 6];
# console.log(findMissingNumber(arr, 6)); // Output: 3
# ```
#
# ---
#
# ### 2. **Flatten a Nested Array**
#
# **Question**: Write a function that flattens a nested array of any depth.
#
# ```javascript
# function flattenArray(arr) {
#     return arr.reduce((acc, curr) => acc.concat(Array.isArray(curr) ? flattenArray(curr) : curr), []);
# }
#
# // Example usage
# const nestedArr = [1, [2, [3, 4, [5]]]];
# console.log(flattenArray(nestedArr)); // Output: [1, 2, 3, 4, 5]
# ```
#
# ---
#
# ### 3. **Find the Maximum Sum of a Subarray of Size K
# **
#
# **Question**: Write a function to find the maximum sum of a contiguous subarray of size K in a given array.
#
# ```javascript
# function maxSumSubarray(arr, K) {
#     let maxSum = 0, windowSum = 0;
#     let left = 0;
#
#     for (let right = 0; right < arr.length; right++) {
#         windowSum += arr[right];
#
#         if (right >= K - 1) {
#             maxSum = Math.max(maxSum, windowSum);
#             windowSum -= arr[left];  // Remove the left element of the window
#             left++;
#         }
#     }
#
#     return maxSum;
# }
#
# // Example usage
# console.log(maxSumSubarray([2, 1, 5, 1, 3, 2], 3)); // Output: 9
# console.log(maxSumSubarray([2, 3, 4, 1, 5], 2));   // Output: 7
#
# ```
#
# ---
#
# ### 4. **Find the Longest Substring Without Repeating Characters**
#
# **Question**: Write a function to find the length of the longest substring without repeating characters.
#
# ```javascript
# function lengthOfLongestSubstring(s) {
#     let map = new Map();
#     let maxLength = 0;
#     let left = 0;
#
#     for (let right = 0; right < s.length; right++) {
#         if (map.has(s[right])) left = Math.max(map.get(s[right]) + 1, left);
#         map.set(s[right], right);
#         maxLength = Math.max(maxLength, right - left + 1);
#     }
#
#     return maxLength;
# }
#
# // Example usage
# console.log(lengthOfLongestSubstring("abcabcbb")); // Output: 3
# ```
#
# ---
#
# ### 5. **Debounce Function**
#
# **Question**: Implement a debounce function that delays the execution of a function until after a specified wait time has passed.
#
# ```javascript
# function debounce(func, wait) {
#     let timeout;
#     return function() {
#         clearTimeout(timeout);
#         timeout = setTimeout(() => func(...arguments), wait);
#     };
# }
#
# // Example usage
# const debouncedLog = debounce(() => console.log("Debounced!"), 2000);
# debouncedLog();
# debouncedLog();
# debouncedLog(); // Output: "Debounced!" after 2 seconds
# ```
#
# ---
#
# ### 6. **Reverse Words in a String**
#
# **Question**: Write a function that reverses the words in a given string while keeping the word order intact.
#
# ```javascript
# function reverseWords(str) {
#     return str.split(' ').reverse().join(' ');
# }
#
# // Example usage
# console.log(reverseWords("Hello World!")); // Output: "World! Hello"
# ```
#
# ---
#
# ### 7. **Sum of Two Numbers in an Array**
#
# **Question**: Write a function to find two numbers in an array that add up to a given target sum.
#
# ```javascript
# function twoSum(arr, target) {
#     const map = new Map();
#     for (let i = 0; i < arr.length; i++) {
#         const complement = target - arr[i];
#         if (map.has(complement)) return [map.get(complement), i];
#         map.set(arr[i], i);
#     }
#     return null;
# }
#
# // Example usage
# const arr = [2, 7, 11, 15];
# console.log(twoSum(arr, 9)); // Output: [0, 1]
# ```
#
# ---
#
# ### 8. **Find the Intersection of Two Arrays**
#
# **Question**: Write a function that finds the intersection of two arrays.
#
# ```javascript
# function intersection(arr1, arr2) {
#     const set1 = new Set(arr1);
#     return arr2.filter(item => set1.has(item));
# }
#
# // Example usage
# console.log(intersection([1, 2, 2, 1], [2, 2])); // Output: [2, 2]
# ```
#
# ---
#
# ### 9. **Merge Sorted Arrays**
#
# **Question**: Write a function that merges two sorted arrays into one sorted array.
#
# ```javascript
# function mergeSortedArrays(arr1, arr2) {
#     let result = [];
#     let i = 0, j = 0;
#     while (i < arr1.length && j < arr2.length) {
#         if (arr1[i] < arr2[j]) result.push(arr1[i++]);
#         else result.push(arr2[j++]);
#     }
#     return result.concat(arr1.slice(i), arr2.slice(j));
# }
#
# // Example usage
# console.log(mergeSortedArrays([1, 3, 5], [2, 4, 6])); // Output: [1, 2, 3, 4, 5, 6]
# ```
#
# ---
#
# ### 10. **Find the First Non-Repeating Character**
#
# **Question**: Write a function to find the first non-repeating character in a string.
#
# ```javascript
# function firstUniqChar(str) {
#     const count = {};
#     for (let char of str) {
#         count[char] = (count[char] || 0) + 1;
#     }
#     for (let char of str) {
#         if (count[char] === 1) return char;
#     }
#     return null;
# }
#
# // Example usage
# console.log(firstUniqChar("leetcode")); // Output: "l"
# ```

# %% [markdown]
# # **Technical Fluency**
#
# **Prepare answers for each question below and understand them so that you can speak and record the answers in the proctored test.**

# %% [markdown]
# ### Technical Questions:
# 1. **How is Node.js better than other frameworks most popularly used??**
#
#
# 2. **Explain the concept of REPL in Node.js?.**
#
#
# 3. **What are the advantages and disadvantages of the microservices architecture?**
#
#
# 4. **How does Node.js overcome the problem of blocking I/O operations?**
#
#
# 5. **What is routing in Express.js, and how does it work?**

# %% [markdown]
# # **Writing & Communication Fluency**
#
# **Write the answer of following question along with a self explanation video.**
#
# - **How would you explain a technical concept like APIs to a non-technical team member?**
#    This tests clarity and the ability to simplify complex ideas. A good response would involve using analogies, such as explaining APIs like a waiter delivering orders from the kitchen to a customer, ensuring the person understands without technical jargon.
